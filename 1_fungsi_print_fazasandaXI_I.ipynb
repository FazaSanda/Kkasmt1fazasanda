# %% [markdown]
# <a href="https://colab.research.google.com/github/FazaSanda/Kkasmt1fazasanda/blob/main/1_fungsi_print_fazasandaXI_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## menampilkan teks bebas

# %%
print("Halo Dunia")
# Out:
# Halo Dunia

# %%
print("Selamat datang di Python")
# Out:
# Selamat datang di Python

# %%
print("Belajar python itu menyenangkan")
# Out:
# Belajar python itu menyenangkan

# %%
print("Faza Sanda")
# Out:
# Faza Sanda

# %% [markdown]
# ## Menampilkan nilai variabel

# %%
nama = "faza"
print(nama)
# Out:
# faza

# %%
BB = 41
print(BB)
# Out:
# 41

# %%
umur = 17
print(umur)
# Out:
# 17

# %% [markdown]
# ## menampilkan Teks Bebas dan Variabel

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
harga_telur = 27000
print("harga telur per 1 kg",harga_telur)
# Out:
# harga telur per 1 kg 27000

# %%
nama_pembeli = "faza"
print("nama pembeli telur adalah" + str(nama_pembeli))
# Out:
# nama pembeli telur adalahfaza

# %%
harga_telur = 26000
print("harga telur per 1 kg adalah" + str (harga_telur))
# Out:
# harga telur per 1 kg adalah26000

# %% [markdown]
# Latihan soal
# 1. Tampllkan teks bebas: Harl inl saya bahagla belajar bahasa python
# 2. Tampllkan nilal varlabel: mata_pelajaran_favorit= Kode dan Kecerdasan Buatan
# 3. Tampllkan nilal variabel: nllal_kka= 100
# 4.Tampilkan teks bebas dan nilai variabel dengan tiga mode (f string,"+",""):"Nilai KKA saya adalah (nilai_kka} loh!'

# %% [markdown]
# ## Escape Character

# %%
print("Nama : Faza Sanda")
print("Kelas : XI-1")
print("Nomor absen : 13")
# Out:
# Nama : Faza Sanda
# Kelas : XI-1
# Nomor absen : 13

# %%
print("Hari ini saya bahagia belajar bahasa python")
# Out:
# Hari ini saya bahagia belajar bahasa python

# %%
mata_pelajaran_favorit = "Agama Islam"
print(mata_pelajaran_favorit)
# Out:
# Agama Islam

# %%
nilai_kka = 100
print(nilai_kka)
# Out:
# 100

# %%
nilai_kka = 98
print("nilai kka saya adalah", nilai_kka, "loh!")
# Out:
# nilai kka saya adalah 98 loh!

# %%
nilai_kka = 98
print(f"nilai kka saya adalah {nilai_kka} loh!")
# Out:
# nilai kka saya adalah 98 loh!

# %%
nilai_kka = 98
print("nilai kka saya adalah " + str(nilai_kka) + " loh!")
# Out:
# nilai kka saya adalah 98 loh!

# %%
print ('Ja\'far shodiq')
# Out:
# Ja'far shodiq

# %% [markdown]
# ## Escape caracter

# %%
print("Ja'far shodiq")
# Out:
# Ja'far shodiq

# %%
print("Bu Shinta berkata, \"semua harus menyimak pelajaran, \"")
# Out:
# Bu Shinta berkata, "semua harus menyimak pelajaran, "

# %%
print("Lokasi file video karnaval ada di D:\\karnaval 2025\\mp4")
# Out:
# Lokasi file video karnaval ada di D:\karnaval 2025\mp4

# %% [markdown]
# Latihan

# %%
Tahun = 2008
Bulan ="September"
Tanggal = 17
print(Tanggal, Bulan, Tahun, sep="-")
# Out:
# 17-September-2008

# %%
Tahun = 2008
Bulan = "September"
Tanggal = 17

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 17/September/2008

# %%
Nama_depan = "Faza"
Nama_belakang = "Sanda"

print(Nama_depan, end=" ")
print(Nama_belakang)
# Out:
# Faza Sanda

# %%
Nama_depan = "Faza"
Nama_belakang = "Sanda"

print(Nama_depan, Nama_belakang)
# Out:
# Faza Sanda

# %%
print("Bu Shinta berkata, \"berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\\Jadwal Pelajaran\\Kelas XI Semester I\"")
print("\n")
print("Jadwal Pelajaran Mingguan")
print("==================================================")
print("Jam\tSenin\t\tSelasa\t\tRabu")
print("Jam 1\tMatematika\tBahasa\t\tInformatika")
print("Jam 2\tBahasa Ing.\tSejarah\t\tMa\'rifatullah")
print("Jam 3\tInformatika\tOlahraga\tBiologi")
# Out:
# Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\Jadwal Pelajaran\Kelas XI Semester I"
#
#
# Jadwal Pelajaran Mingguan
# ==================================================
# Jam	Senin		Selasa		Rabu
# Jam 1	Matematika	Bahasa		Informatika
# Jam 2	Bahasa Ing.	Sejarah		Ma'rifatullah
# Jam 3	Informatika	Olahraga	Biologi

# %% [markdown]
# ## parameter fungsi

# %%
nama_siswa_1="Faza"
nama_siswa_2="kaisya"
nama_siswa_3 ="Humaira"
nama_siswa_4 ="Fazila"
print(nama_siswa_1, nama_siswa_2, nama_siswa_3, nama_siswa_4, sep="-")
# Out:
# Faza-kaisya-Humaira-Fazila

# %%
print(nama_siswa_1, end="-")
print(nama_siswa_2)
print(nama_siswa_3,end="-")
print(nama_siswa_4)
# Out:
# Faza-kaisya
# Humaira-Fazila
